# %% [markdown]
# <a href="https://colab.research.google.com/github/chenkenanalytic/ai_tutorial_class/blob/main/lesson%201/python_web_scraping_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 淡江 AI 就業學分學程 - 業師專題(一) 網路爬蟲實作
#
# 講師：陳柏銓 (陳肯 - Chen Ken)
#
# Github link: https://github.com/chenkenanalytic

# %% [markdown]
# ### import 需要的套件

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 找到爬蟲網址

# %%
weblink = 'https://www.ptt.cc/bbs/DSLR/M.1615306457.A.825.html'

# %% [markdown]
# ### 開始爬蟲

# %%
# 定義 headers 模擬瀏覽器 呼叫網頁資訊
headers = {
    	'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
      }

# 使用 requests 套件
res = requests.get(weblink, headers=headers)

# 將網頁程式碼以 UTF-8 做讀取格式
res.encoding = 'UTF-8'

# 用 beautifulsoup 處理 html
soup = BeautifulSoup(res.text, 'html.parser')

# print 出 html
print(soup)

# %% [markdown]
# ### 找出圖片網址

# %%
for link in soup.find_all('a'):
  print(link.get('href'))

# %% [markdown]
# ### 課程小作業：進階開發 - 儲存網址圖片到 google drive 上
#
# Hint: 透過迴圈判別是否為圖片，再開啟圖片網址，儲存圖片到雲端硬碟

# %% [markdown]
# Step 1. 與 google dirve 做連結

# %%
### CODE - 2 line ###


### END ###
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 2. 建立圖片儲存資料夾 (使用 os 套件)
#
# Hint: google 關鍵字 - os 建立資料夾

# %%
import os

### Code - 1 line ###

### END ###

# %% [markdown]
# Step 3. 使用迴圈處理連結，並儲存圖片
#
# Hint 1: 參考使用上方 "找出圖片網址" 教學程式碼
#
# Hint 2: google 關鍵字 - python 圖片網址 儲存

# %%
### Code - 6 line ###






### END ###
